# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
# %matplotlib inline

# %%
import matplotlib as mpl

def display_image_in_actual_size(im_path):

    dpi = mpl.rcParams['figure.dpi']
    im_data = plt.imread(im_path)
    height, width, depth = im_data.shape

    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    ax.imshow(im_data, cmap='gray')

    plt.show()

# %% [markdown]
# ## Gamma Distribution
# * created as gamma distribution
# * random sampled size of (5, 2, 15 or 30) and used the samples as fixation durations

# %%
display_image_in_actual_size('/Users/h/Dropbox/Projects/SI.01/coding/design/gamma.png')

# %% [markdown]
# # 1. one session

# %% [markdown]
# ## 1.1 version 1
# * 15 trials (5 neutral, 8 congruent, 2 incongruent)
# * cue 2s
# * target + response 1.5s
# * EFFECT REQUIRED: 1.761

# %% [markdown]
# ## 1.2 version 2
# * 30 trials (10 neutral, 16 congruent, 4 incongruent)
# * cue 2s
# * target + response 1.5s
# * EFFECT REQUIRED: 1.140

# %% [markdown]
# ## 1.3 version 3
# * 30 trials (10 neutral, 16 congruent, 4 incongruent)
# * cue 2s
# * target + response 2.5s
# * EFFECT REQUIRED: 1.080

# %%
m3_img = '/Users/h/Dropbox/Projects/SI.01/model_30_longerdur_efficiency.png'
display_image_in_actual_size(m3_img)

# %% [markdown]
# ## 1.4 Poker as reference

# %%
poker_img = '/Users/h/Dropbox/Projects/SI.01/poker_session1.png'
# img= mpimg.imread(poker_img)
# imgplot = plt.imshow(img)
display_image_in_actual_size(poker_img)

# %% [markdown]
# # 2. total length - version 3

# %% [markdown]
# * jitter: total 880.6 sec (pre-calculated gamma-dist jitter)
# * total of 300 trials
# * 37 minutes + 30s break between session? = 41.5 min

# %% [markdown]
# # 3. Questions
# * Probably blocked.. but event related? or blocked? (intermixing own special interest, other special interest, mother, arrow conditions)
# * congruent vs incongruent trial ratio = 8:2 in a standard posner cueing paradigm.
#     8:2 in order to establish a valid cue and to investigate the effect of a cue, modulating attention
# * analysis difficulty with unequal Ns?
